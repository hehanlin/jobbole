# %%
import requests

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
}

# %%
resp = requests.get("https://www.zhipin.com/", headers=headers)

# %%
resp.text
# Out:
# '\n\n\n\n\n\n<!DOCTYPE html>\n<!--[if lt IE 7 ]><html class="ie ie6"><![endif]-->\n<!--[if IE 7 ]><html class="ie ie7"><![endif]-->\n<!--[if IE 8 ]><html class="ie ie8"><![endif]-->\n<!--[if IE 9 ]><html class="ie9"><![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--><html class="standard"><!--<![endif]-->\n<head>\n    <meta charset="utf-8">\n    <title>BOSS直聘-互联网招聘神器！</title>\n    <meta name="keywords" content="BOSS直聘,直聘网,招聘网,人才网,找工作"/>\n    <meta name="description" content="BOSS直聘是权威领先的招聘网，开启人才网招聘求职新时代，让求职者与Boss直接开聊、加快面试、即时反馈，找工作就来BOSS直聘和Boss开聊吧！"/>\n    <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.bosszhipin.com/">\n    <link href="/v2/web/geek/css/main.css" type="text/css" rel="stylesheet">\n</head>\n<body>\n\n<div id="wrap">\n    \n\n\n\n\n<script>\n    _PAGE={\n        checkMobileUrl:"/registe/sendSms.json",\n        regMobileUrl:"/registe/save.json",\n        loginMobileUrl:"/login/phone.json",\n        loginAccountUrl:"/login/account.json",\n        getRandomKeyUrl:"/captcha/randkey.json",\n        verifyImgUrl:"/captcha/?randomKey={randomKey}",\n        getPositionUrl:"/user/position.json",\n        skillsUrl:"/webscan/positionSkill"\n        \n    }\n</script>\n\n\n<div id="header">\n    <div class="inner">\n        <h1 class="logo"><a href="https://www.zhipin.com/" ka="header-home-logo" title="BOSS直聘"><span>BOSS直聘</span></a></h1>\n        <div class="nav">\n            <ul>\n                <li class="cur"><a ka="header-home"  href="https://www.zhipin.com/" >首页</a></li>\n                <li class=""><a ka="header-job" href="https://www.zhipin.com/job_detail/" >求职</a></li>\n                <li class=""><a ka="header-app" href="https://app.zhipin.com/" >APP</a></li>\n                <li class=""><a ka="header-article" href="https://news.zhipin.com/" >资讯</a></li>\n            </ul>\n        </div>\n        \n        <div class="user-nav">\n            \n                \n                <!--未登录-->\n                <div class="btns"><a href="https://sao.zhipin.com" ka="header-sao" class="link-scan">Boss 扫码登录</a><a href="https://signup.zhipin.com" ka="header-register"  class="btn btn-outline" >注册</a><a href="https://login.zhipin.com" ka="header-login"  class="btn btn-outline" >登录</a></div>\n                \n            \n            \n        </div>\n    </div>\n</div>\n    \n    <div id="main" class="inner">\n        <div class="home-box">\n            <div class="home-sider">\n                <!-- 左侧职位选择 -->\n                <div class="job-menu">\n                    <dl>\n                        <dt><i class="icon-arrow-right"></i>所有行业</dt>\n                        \n                        <dd>\n                            <a href="/c101010100/?query=%E4%BA%92%E8%81%94%E7%BD%91" ka="cpc_side_520">互联网</a>\n                            <a href="/c101010100/?query=%E7%A7%BB%E5%8A%A8%E4%BA%92%E8%81%94%E7%BD%91" ka="cpc_side_520">移动互联网</a>\n                            <a href="/c101010100/?query=%E4%BC%A0%E5%AA%92" ka="cpc_side_520">传媒</a>\n                            <a href="/c101010100/?query=%E9%87%91%E8%9E%8D" ka="cpc_side_520">金融</a>\n                            <a href="/c101010100/?query=%E6%95%99%E8%82%B2" ka="cpc_side_520">教育</a>\n                            <a href="/c101010100/?query=%E6%88%BF%E5%9C%B0%E4%BA%A7" ka="cpc_side_520">房地产</a>\n                            <a href="/c101010100/?query=%E6%B1%BD%E8%BD%A6" ka="cpc_side_520">汽车</a>\n                            <a href="/c101010100/?query=%E4%BE%9B%E5%BA%94%E9%93%BE" ka="cpc_side_520">供应链</a>\n                        </dd>\n                        <div class="menu-line"></div>\n                        <!--全部职位-->\n                        <div class="menu-sub menu-all">\n                            <div class="sub-tab">\n                                <ul>\n                                    \n                                        <li class="cur">传媒</li>\n                                    \n                                ...

# %%
import lxml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-3a2be3d699bf> in <module>()
# ----> 1 import lxml
#
# ModuleNotFoundError: No module named 'lxml'

# %%
from lxml import etree

# %%
html = etree.HTML(resp.text)

# %%
tag_list = html.xpath("//div[@class='menu-sub']//a/text()|//div[@class='menu-sub']//a/@href")

# %%
# Out:
# ['/c101010100-p100101/',
#  'Java',
#  '/c101010100-p100102/',
#  'C++',
#  '/c101010100-p100103/',
#  'PHP',
#  '/c101010100-p100104/',
#  '数据挖掘',
#  '/c101010100-p100105/',
#  'C',
#  '/c101010100-p100106/',
#  'C#',
#  '/c101010100-p100107/',
#  '.NET',
#  '/c101010100-p100108/',
#  'Hadoop',
#  '/c101010100-p100109/',
#  'Python',
#  '/c101010100-p100110/',
#  'Delphi',
#  '/c101010100-p100111/',
#  'VB',
#  '/c101010100-p100112/',
#  'Perl',
#  '/c101010100-p100113/',
#  'Ruby',
#  '/c101010100-p100114/',
#  'Node.js',
#  '/c101010100-p100115/',
#  '搜索算法',
#  '/c101010100-p100116/',
#  'Golang',
#  '/c101010100-p100117/',
#  '自然语言处理',
#  '/c101010100-p100118/',
#  '推荐算法',
#  '/c101010100-p100119/',
#  'Erlang',
#  '/c101010100-p100120/',
#  '算法工程师',
#  '/c101010100-p100121/',
#  '语音/视频/图形开发',
#  '/c101010100-p100122/',
#  '数据采集',
#  '/c101010100-p100201/',
#  'HTML5',
#  '/c101010100-p100202/',
#  'Android',
#  '/c101010100-p100203/',
#  'iOS',
#  '/c101010100-p100204/',
#  'WP',
#  '/c101010100-p100205/',
#  'web前端',
#  '/c101010100-p100206/',
#  'Flash',
#  '/c101010100-p100208/',
#  'JavaScript',
#  '/c101010100-p100209/',
#  'U3D',
#  '/c101010100-p100210/',
#  'COCOS2DX',
#  '/c101010100-p100301/',
#  '测试工程师',
#  '/c101010100-p100302/',
#  '自动化测试',
#  '/c101010100-p100303/',
#  '功能测试',
#  '/c101010100-p100304/',
#  '性能测试',
#  '/c101010100-p100305/',
#  '测试开发',
#  '/c101010100-p100306/',
#  '移动端测试',
#  '/c101010100-p100307/',
#  '游戏测试',
#  '/c101010100-p100308/',
#  '硬件测试',
#  '/c101010100-p100309/',
#  '软件测试',
#  '/c101010100-p100401/',
#  '运维工程师',
#  '/c101010100-p100402/',
#  '运维开发工程师',
#  '/c101010100-p100403/',
#  '网络工程师',
#  '/c101010100-p100404/',
#  '系统工程师',
#  '/c101010100-p100405/',
#  'IT技术支持',
#  '/c101010100-p100406/',
#  '系统管理员',
#  '/c101010100-p100407/',
#  '网络安全',
#  '/c101010100-p100408/',
#  '系统安全',
#  '/c101010100-p100409/',
#  'DBA',
#  '/c101010100-p100506/',
#  'ETL工程师',
#  '/c101010100-p100507/',
#  '数据仓库',
#  '/c101010100-p100508/',
#  '数据开发',
#  '/c101010100-p100509/',
#  '数据挖掘',
#  '/c101010100-p100511/',
#  '数据分析师',
#  '/c101010100-p100512/',
#  '数据架构师',
#  '/c101010100-p100513/',
#  '算法研究员',
#  '/c101010100-p100601/',
#  '项目经理',
#  '/c101010100-p100602/',
#  '项目主管',
#  '/c101010100-p100603/',
#  '项目助理',
#  '/c101010100-p100604/',
#  '项目专员',
#  '/c101010100-p100605/',
#  '实施顾问',
#  '/c101010100-p100606/',
#  '实施工程师',
#  '/c101010100-p100607/',
#  '需求分析工程师',
#  '/c101010100-p100801/',
#  '硬件',
#  '/c101010100-p100802/',
#  '嵌入式',
#  '/c101010100-p100803/',
#  '自动化',
#  '/c101010100-p100804/',
#  '单片机',
#  '/c101010100-p100805/',
#  '电路设计',
#  '/c101010100-p100806/',
#  '驱动开发',
#  '/c101010100-p100807/',
#  '系统集成',
#  '/c101010100-p100808/',
#  'FPGA开发',
#  '/c101010100-p100809/',
#  'DSP开发',
#  '/c101010100-p100810/',
#  'ARM开发',
#  '/c101010100-p100811/',
#  'PCB工艺',
#  '/c101010100-p100812/',
#  '模具设计',
#  '/c101010100-p100813/',
#  '热传导',
#  '/c101010100-p100814/',
#  '材料工程师',
#  '/c101010100-p100815/',
#  '精益工程师',
#  '/c101010100-p100816/',
#  '射频工程师',
#  '/c101010100-p100901/',
#  'web前端',
#  '/c101010100-p100902/',
#  'Javascript',
#  '/c101010100-p100903/',
#  'Flash',
#  '/c101010100-p100904/',
#  'HTML5',
#  '/c101010100-p101001/',
#  '通信技术工程师',
#  '/c101010100-p101002/',
#  '通信研发工程师',
#  '/c101010100-p101003/',
#  '数据通信工程师',
#  '/c101010100-p101004/',
#  '移动通信工程师',
#  '/c101010100-p101005/',
#  '电信网络工程师',
#  '/c101010100-p101006/',
#  '电信交换工程师',
#  '/c101010100-p101007/',
#  '有线传输工程师',
#  '/c101010100-p101008/',
#  '无线射频工程师',
#  '/c101010100-p101009/',
#  '通信电源工程师',
#  '/c101010100-p101010/',
#  '通信标准化工程师',
#  '/c101010100-p101011/',
#  '通信项目专员',
#  '/c101010100-p101012/',
#  '通信项目经理',
#  '/c101010100-p101013/',
#  '核心网工程师',
#  '/c101010100-p101014/',
#  '通信测试工程师',
#  '/c101010100-p101015/',
#  '通信设备工程师',
#  '/c101010100-p101016/',
#  '光通信工程师',
#  '/c101010100-p101017/',
#  '光传输工程师',
#  '/c101010100-p101018/',
#  '光网络工程师',
#  '/c101010100-p100701/',
#  '技术经理',
#  '/c101010100-p100702/',
#  '技术总监',
#  '/c101010100-p100703/',
#  '测试经理',
#  '/c101010100-p100704/',
#  '架构师',
#  '/c101010100-p100705/',
#  'CTO',
#  '/c101010100-p100706/',
#  '运维总监',
#  '/c101010100-p100707/',
#  '技术合伙人',
#  '/c101010100-p101301/',
#  '机器学习',
#  '/c101010100-p101302/',
#  '深度学习',
#  '/c101010100-p101303/',
#  '图像算法',
#  '/c101010100-p101304/',
#  '图像处理',
#  '/c101010100-p101305/',
#  '语音识别',
#  '/c101010100-p101306/',
#  '图像识别',
#  '/c101010100-p101307/',
#  '算法研究员',
#  '/c101010100-p101201/',
#  '售前工程师',
#  '/c101010100-p101202/',
#  '售后工程师',
#  '/c101010100-p101101/',
#  '其他技术职位',
#  '/c101010100-p110101/',
#  '产品经理',
#  '/c101010100-p110102/',
#  '网页产品经理',
#  '/c101010100-p110103/',
#  '移动产品经理',
#  '/c101010100-p110104/',
#  '产品助理',
#  '/c101010100-p110105/',
#  '数据产品经理',
#  '/c101010100-p110106/',
#  '电商产品经理',
#  '/c101010100-p110107/',
#  '游戏策划',
#  '/c101010100-p110108/',
#  '产品专员',
#  '/c101010100-p110302/',
#  '产品总监',
#  '/c101010100-p110303/',
#  '游戏制作人',
#  '/c101010100-p110304/',
#  '产品VP',
#  '/c101010100-p110401/',
#  '其他产品职位',
#  '/c101010100-p120101/',
#  '视觉设计师',
#  '/c101010100-p120102/',
#  '网页设计师',
#  '/c101010100-p120103/',
#  'Flash设计师',
#  '/c101010100-p120104/',
#  'APP设计师',
#  '/c101010100-p120105/',
#  'UI设计师',
#  '/c101010100-p120106/',
#  '平面设计师',
#  '/c101010100-p120107/',
#  '美术设计师（2D/3D）',
#  '/c101010100-p120108/',
#  '广告设计师',
#  '/c101010100-p120109/',
#  '多媒体设计师',
#  '/c101010100-p120110/',
#  '原画师',
#  '/c101010100-p120111/',
#  '游戏特效',
#  '/c101010100-p120112/',
#  '游戏界面设计师',
#  '/c101010100-p120113/',
#  '游戏场景',
#  '/c101010100-p120114/',
#  '游戏角色',
#  '/c101010100-p120115/',
#  '游戏动作',
#  '/c101010100-p120116/',
#  '三维/CAD/制图',
#  '/c101010100-p120117/',
#  '美工',
#  '/c101010100-p120118/',
#  '包装设计',
#  '/c101010100-p120119/',
#  '设计师助理',
#  '/c101010100-p120120/',
#  '动画设计师',
#  '/c101010100-p120121/',
#  '插画师',
#  '/c101010100-p120201/',
#  '交互设计师',
#  '/c101010100-p120202/',
#  '无线交互设计师',
#  '/c101010100-p120203/',
#  '网页交互设计师',
#  '/c101010100-p120204/',
#  '硬件交互设计师',
#  '/c101010100-p120301/',
#  '数据分析师',
#  '/c101010100-p120302/',
#  '用户研究员',
#  '/c101010100-p120303/',
#  '游戏数值策划',
#  '/c101010100-p120304/',
#  'UX设计师',
#  '/c101010100-p120407/',
#  '用户研究经理',
#  '/c101010100-p120408/',
#  '用户研究总监',
#  '/c101010100-p120401/',
#  '设计经理/主管',
#  '/c101010100-p120402/',
#  '设计总监',
#  '/c101010100-p120403/',
#  '视觉设计经理',
#  '/c101010100-p120404/',
#  '视觉设计总监',
#  '/c101010100-p120405/',
#  '交互设计经理/主管',
#  '/c101010100-p120406/',
#  '交互设计总监',
#  '/c101010100-p120601/',
#  '服装设计',
#  '/c101010100-p120602/',
#  '工业设计',
#  '/c101010100-p120603/',
#  '橱柜设计',
#  '/c101010100-p120604/',
#  '家具设计',
#  '/c101010100-p120605/',
#  '家居设计',
#  '/c101010100-p120606/',
#  '珠宝设计',
#  '/c101010100-p120607/',
#  '室内设计',
#  '/c101010100-p120608/',
#  '陈列设计',
#  '/c101010100-p120610/',
#  '景观设计',
#  '/c101010100-p120501/',
#  '其他设计职位',
#  '/c101010100-p130101/',
#  '用户运营',
#  '/c101010100-p130102/',
#  '产品运营',
#  '/c101010100-p130103/',
#  '数据运营',
#  '/c101010100-p130104/',
#  '内容运营',
#  '/c101010100-p130105/',
#  '活动运营',
#  '/c101010100-p130106/',
#  '商家运营',
#  '/c101010100-p130107/',
#  '品类运营',
#  '/c101010100-p130108/',
#  '游戏运营',
#  '/c101010100-p130109/',
#  '网络推广',
#  '/c101010100-p130110/',
#  '网站运营',
#  '/c101010100-p130111/',
#  '新媒体运营',
#  '/c101010100-p130112/',
#  '社区运营',
#  '/c101010100-p130113/',
#  '微信运营',
#  '/c101010100-p130114/',
#  '微博运营',
#  '/c101010100-p130115/',
#  '策略运营',
#  '/c101010100-p130116/',
#  '线下拓展运营',
#  '/c101010100-p130117/',
#  '电商运营',
#  '/c101010100-p130118/',
#  '运营助理/专员',
#  '/c101010100-p130119/',
#  '销售运营',
#  '/c101010100-p130201/',
#  '副主编',
#  '/c101010100-p130202/',
#  '内容编辑',
#  '/c101010100-p130203/',
#  '文案策划',
#  '/c101010100-p130204/',
#  '网站编辑',
#  '/c101010100-p130205/',
#  '记者',
#  '/c101010100-p130206/',
#  '采编',
#  '/c101010100-p130301/',
#  '售前咨询',
#  '/c101010100-p130302/',
#  '售后咨询',
#  '/c101010100-p130303/',
#  '网络客服',
#  '/c101010100-p130304/',
#  '客服经理',
#  '/c101010100-p130305/',
#  '客服专员/助理',
#  '/c101010100-p130306/',
#  '客服主管',
#  '/c101010100-p130307/',
#  '客服总监',
#  '/c101010100-p130308/',
#  '电话客服',
#  '/c101010100-p130309/',
#  '咨询热线/呼叫中心客服',
#  '/c101010100-p130401/',
#  '主编',
#  '/c101010100-p130402/',
#  '运营总监',
#  '/c101010100-p130403/',
#  'COO',
#  '/c101010100-p130404/',
#  '客服总监',
#  '/c101010100-p130405/',
#  '运营经理/主管',
#  '/c101010100-p130501/',
#  '其他运营职位',
#  '/c101010100-p140101/',
#  '市场营销',
#  '/c101010100-p140102/',
#  '市场策划',
#  '/c101010100-p140103/',
#  '市场顾问',
#  '/c101010100-p140104/',
#  '市场推广',
#  '/c101010100-p140105/',
#  'SEO',
#  '/c101010100-p140106/',
#  'SEM',
#  '/c101010100-p140107/',
#  '商务渠道',
#  '/c101010100-p140108/',
#  '商业数据分析',
#  '/c101010100-p140109/',
#  '活动策划',
#  '/c101010100-p140110/',
#  '网络营销',
#  '/c101010100-p140111/',
#  '海外市场',
#  '/c101010100-p140112/',
#  '政府关系',
#  '/c101010100-p140201/',
#  '媒介经理',
#  '/c101010100-p140202/',
#  '广告协调',
#  '/c101010100-p140203/',
#  '品牌公关',
#  '/c101010100-p140204/',
#  '媒介专员',
#  '/c101010100-p140205/',
#  '活动策划执行',
#  '/c101010100-p140206/',
#  '媒介策划',
#  '/c101010100-p140501/',
#  '会议活动销售',
#  '/c101010100-p140502/',
#  '会议活动策划',
#  '/c101010100-p140503/',
#  '会议活动执行',
#  '/c101010100-p140504/',
#  '会展活动销售',
#  '/c101010100-p140505/',
#  '会展活动策划',
#  '/c101010100-p140506/',
#  '会展活动执行',
#  '/c101010100-p140601/',
#  '广告创意',
#  '/c101010100-p140602/',
#  '美术指导',
#  '/c101010100-p140603/',
#  '广告设计师',
#  '/c101010100-p140604/',
#  '策划经理',
#  '/c101010100-p140605/',
#  '文案',
#  '/c101010100-p140607/',
#  '广告制作',
#  '/c101010100-p140608/',
#  '媒介投放',
#  '/c101010100-p140609/',
#  '媒介合作',
#  '/c101010100-p140610/',
#  '媒介顾问',
#  '/c101010100-p140611/',
#  '广告审核',
#  '/c101010100-p140401/',
#  '市场总监',
#  '/c101010100-p140404/',
#  'CMO',
#  '/c101010100-p140405/',
#  '公关总监',
#  '/c101010100-p140406/',
#  '媒介总监',
#  '/c101010100-p140407/',
#  '创意总监',
#  '/c101010100-p140701/',
#  '其他市场职位',
#  '/c101010100-p150101/',
#  '人力资源主管',
#  '/c101010100-p150102/',
#  '招聘',
#  '/c101010100-p150103/',
#  'HRBP',
#  '/c101010100-p150104/',
#  '人力资源专员/助理',
#  '/c101010100-p150105/',
#  '培训',
#  '/c101010100-p150106/',
#  '薪资福利',
#  '/c101010100-p150107/',
#  '绩效考核',
#  '/c101010100-p150403/',
#  '人力资源经理',
#  '/c101010100-p150406/',
#  '人力资源VP/CHO',
#  '/c101010100-p150108/',
#  '人力资源总监',
#  '/c101010100-p150109/',
#  '员工关系',
#  '/c101010100-p150110/',
#  '组织发展',
#  '/c101010100-p150201/',
#  '行政专员/助理',
#  '/c101010100-p150202/',
#  '前台',
#  '/c101010100-p150204/',
#  '行政主管',
#  '/c101010100-p150205/',
#  '经理助理',
#  '/c101010100-p150207/',
#  '后勤',
#  '/c101010100-p150208/',
#  '商务司机',
#  '/c101010100-p150401/',
#  '行政经理',
#  '/c101010100-p150209/',
#  '行政总监',
#  '/c101010100-p150301/',
#  '会计',
#  '/c101010100-p150302/',
#  '出纳',
#  '/c101010100-p150303/',
#  '财务顾问',
#  '/c101010100-p150304/',
#  '结算',
#  '/c101010100-p150305/',
#  '税务',
#  '/c101010100-p150306/',
#  '审计',
#  '/c101010100-p150307/',
#  '风控',
#  '/c101010100-p150402/',
#  '财务经理',
#  '/c101010100-p150404/',
#  'CFO',
#  '/c101010100-p150308/',
#  '财务总监',
#  '/c101010100-p150309/',
#  '财务主管',
#  '/c101010100-p150203/',
#  '法务专员/助理',
#  '/c101010100-p150502/',
#  '律师',
#  '/c101010100-p150503/',
#  '专利',
#  '/c101010100-p150504/',
#  '法律顾问',
#  '/c101010100-p150505/',
#  '法务主管',
#  '/c101010100-p150506/',
#  '法务经理',
#  '/c101010100-p150507/',
#  '法务总监',
#  '/c101010100-p150407/',
#  'CEO/总裁/总经理',
#  '/c101010100-p150408/',
#  '副总裁/副总经理',
#  '/c101010100-p150409/',
#  '事业部负责人',
#  '/c101010100-p150410/',
#  '区域/分公司/代表处负责人',
#  '/c101010100-p150411/',
#  '总裁/总经理/董事长助理',
#  '/c101010100-p150412/',
#  '合伙人',
#  '/c101010100-p150413/',
#  '创始人',
#  '/c101010100-p150414/',
#  '董事会秘书',
#  '/c101010100-p150601/',
#  '其他职能职位',
#  '/c101010100-p140301/',
#  '销售专员',
#  '/c101010100-p140302/',
#  '销售经理',
#  '/c101010100-p140303/',
#  '客户代表',
#  '/c101010100-p140304/',
#  '大客户代表',
#  '/c101010100-p140305/',
#  'BD经理',
#  '/c101010100-p140306/',
#  '商务渠道',
#  '/c101010100-p140307/',
#  '渠道销售',
#  '/c101010100-p140308/',
#  '代理商销售',
#  '/c101010100-p140309/',
#  '销售助理',
#  '/c101010100-p140310/',
#  '电话销售',
#  '/c101010100-p140311/',
#  '销售顾问',
#  '/c101010100-p140312/',
#  '商品经理',
#  '/c101010100-p140313/',
#  '广告销售',
#  '/c101010100-p140314/',
#  '网络营销',
#  '/c101010100-p140315/',
#  '营销主管',
#  '/c101010100-p140402/',
#  '销售总监',
#  '/c101010100-p140403/',
#  '商务总监',
#  '/c101010100-p160101/',
#  '区域总监',
#  '/c101010100-p160102/',
#  '城市经理',
#  '/c101010100-p160103/',
#  '销售VP',
#  '/c101010100-p160104/',
#  '团队经理',
#  '/c101010100-p160201/',
#  '其他销售职位',
#  '/c101010100-p170101/',
#  '记者',
#  '/c101010100-p170102/',
#  '编辑',
#  '/c101010100-p170103/',
#  '采编',
#  '/c101010100-p170104/',
#  '撰稿人',
#  '/c101010100-p170105/',
#  '出版发行',
#  '/c101010100-p170106/',
#  '校对录入',
#  '/c101010100-p170107/',
#  '总编',
#  '/c101010100-p170108/',
#  '自媒体',
#  '/c101010100-p170301/',
#  '媒介经理',
#  '/c101010100-p170302/',
#  '媒介专员',
#  '/c101010100-p170303/',
#  '广告协调',
#  '/c101010100-p170304/',
#  '品牌公关',
#  '/c101010100-p170305/',
#  '活动策划执行',
#  '/c101010100-p170306/',
#  '媒介策划',
#  '/c101010100-p170401/',
#  '会议活动销售',
#  '/c101010100-p170402/',
#  '会议活动策划',
#  '/c101010100-p170403/',
#  '会议活动执行',
#  '/c101010100-p170404/',
#  '会展活动销售',
#  '/c101010100-p170405/',
#  '会展活动策划',
#  '/c101010100-p170406/',
#  '会展活动执行',
#  '/c101010100-p170201/',
#  '广告创意',
#  '/c101010100-p170202/',
#  '美术指导',
#  '/c101010100-p170203/',
#  '广告设计师',
#  '/c101010100-p170204/',
#  '策划经理',
#  '/c101010100-p170205/',
#  '文案',
#  '/c101010100-p170207/',
#  '广告制作',
#  '/c101010100-p170208/',
#  '媒介投放',
#  '/c101010100-p170209/',
#  '媒介合作',
#  '/c101010100-p170210/',
#  '媒介顾问',
#  '/c101010100-p170211/',
#  '广告审核',
#  '/c101010100-p170617/',
#  '助理',
#  '/c101010100-p170618/',
#  '统筹制片人',
#  '/c101010100-p170619/',
#  '执行制片人',
#  '/c101010100-p170601/',
#  '导演/编导',
#  '/c101010100-p170602/',
#  '摄影/影像师',
#  '/c101010100-p170603/',
#  '视频编辑',
#  '/c101010100-p170604/',
#  '音频编辑',
#  '/c101010100-p170605/',
#  '经纪人',
#  '/c101010100-p170606/',
#  '后期制作',
#  '/c101010100-p170607/',
#  '影视制作',
#  '/c101010100-p170608/',
#  '影视发行',
#  '/c101010100-p170609/',
#  '影视策划',
#  '/c101010100-p170610/',
#  '主持人/主播/DJ',
#  '/c101010100-p170611/',
#  '演员/配音/模特',
#  '/c101010100-p170612/',
#  '化妆/造型/服装',
#  '/c101010100-p170613/',
#  '放映管理',
#  '/c101010100-p170614/',
#  '录音/音效',
#  '/c101010100-p170615/',
#  '制片人',
#  '/c101010100-p170616/',
#  '编剧',
#  '/c101010100-p170501/',
#  '其他传媒职位',
#  '/c101010100-p180101/',
#  '投资经理',
#  '/c101010100-p180103/',
#  '行业研究',
#  '/c101010100-p180104/',
#  '资产管理',
#  '/c101010100-p180112/',
#  '投资总监',
#  '/c101010100-p180113/',
#  '投资VP',
#  '/c101010100-p180114/',
#  '投资合伙人',
#  '/c101010100-p180115/',
#  '融资',
#  '/c101010100-p180116/',
#  '并购',
#  '/c101010100-p180117/',
#  '投后管理',
#  '/c101010100-p180118/',
#  '投资助理',
#  '/c101010100-p180111/',
#  '其他投融资职位',
#  '/c101010100-p180119/',
#  '投资顾问',
#  '/c101010100-p180201/',
#  '风控',
#  '/c101010100-p180202/',
#  '律师',
#  '/c101010100-p180203/',
#  '资信评估',
#  '/c101010100-p180204/',
#  '合规稽查',
#  '/c101010100-p180301/',
#  '审计',
#  '/c101010100-p180302/',
#  '法务',
#  '/c101010100-p180303/',
#  '会计',
#  '/c101010100-p180304/',
#  '清算',
#  '/c101010100-p180401/',
#  '信用卡销售',
#  '/c101010100-p180102/',
#  '分析师',
#  '/c101010100-p180402/',
#  '柜员',
#  '/c101010100-p180403/',
#  '商务渠道',
#  '/c101010100-p180404/',
#  '大堂经理',
#  '/c101010100-p180105/',
#  '理财顾问',
#  '/c101010100-p180405/',
#  '客户经理',
#  '/c101010100-p180406/',
#  '信贷管理',
#  '/c101010100-p180107/',
#  '风控',
#  '/c101010100-p180501/',
#  '金融产品经理',
#  '/c101010100-p180502/',
#  '风控',
#  '/c101010100-p180503/',
#  '催收员',
#  '/c101010100-p180504/',
#  '分析师',
#  '/c101010100-p180505/',
#  '投资经理',
#  '/c101010100-p180106/',
#  '交易员',
#  '/c101010100-p180506/',
#  '理财顾问',
#  '/c101010100-p180108/',
#  '合规稽查',
#  '/c101010100-p180109/',
#  '审计',
#  '/c101010100-p180110/',
#  '清算',
#  '/c101010100-p180701/',
#  '保险业务',
#  '/c101010100-p180702/',
#  '精算师',
#  '/c101010100-p180703/',
#  '保险理赔',
#  '/c101010100-p180601/',
#  '其他金融职位',
#  '/c101010100-p180801/',
#  '证券经纪人',
#  '/c101010100-p180802/',
#  '证券分析师']

# %%
tag_list
# Out:
# ['Java',
#  'C++',
#  'PHP',
#  '数据挖掘',
#  'C',
#  'C#',
#  '.NET',
#  'Hadoop',
#  'Python',
#  'Delphi',
#  'VB',
#  'Perl',
#  'Ruby',
#  'Node.js',
#  '搜索算法',
#  'Golang',
#  '自然语言处理',
#  '推荐算法',
#  'Erlang',
#  '算法工程师',
#  '语音/视频/图形开发',
#  '数据采集',
#  'HTML5',
#  'Android',
#  'iOS',
#  'WP',
#  'web前端',
#  'Flash',
#  'JavaScript',
#  'U3D',
#  'COCOS2DX',
#  '测试工程师',
#  '自动化测试',
#  '功能测试',
#  '性能测试',
#  '测试开发',
#  '移动端测试',
#  '游戏测试',
#  '硬件测试',
#  '软件测试',
#  '运维工程师',
#  '运维开发工程师',
#  '网络工程师',
#  '系统工程师',
#  'IT技术支持',
#  '系统管理员',
#  '网络安全',
#  '系统安全',
#  'DBA',
#  'ETL工程师',
#  '数据仓库',
#  '数据开发',
#  '数据挖掘',
#  '数据分析师',
#  '数据架构师',
#  '算法研究员',
#  '项目经理',
#  '项目主管',
#  '项目助理',
#  '项目专员',
#  '实施顾问',
#  '实施工程师',
#  '需求分析工程师',
#  '硬件',
#  '嵌入式',
#  '自动化',
#  '单片机',
#  '电路设计',
#  '驱动开发',
#  '系统集成',
#  'FPGA开发',
#  'DSP开发',
#  'ARM开发',
#  'PCB工艺',
#  '模具设计',
#  '热传导',
#  '材料工程师',
#  '精益工程师',
#  '射频工程师',
#  'web前端',
#  'Javascript',
#  'Flash',
#  'HTML5',
#  '通信技术工程师',
#  '通信研发工程师',
#  '数据通信工程师',
#  '移动通信工程师',
#  '电信网络工程师',
#  '电信交换工程师',
#  '有线传输工程师',
#  '无线射频工程师',
#  '通信电源工程师',
#  '通信标准化工程师',
#  '通信项目专员',
#  '通信项目经理',
#  '核心网工程师',
#  '通信测试工程师',
#  '通信设备工程师',
#  '光通信工程师',
#  '光传输工程师',
#  '光网络工程师',
#  '技术经理',
#  '技术总监',
#  '测试经理',
#  '架构师',
#  'CTO',
#  '运维总监',
#  '技术合伙人',
#  '机器学习',
#  '深度学习',
#  '图像算法',
#  '图像处理',
#  '语音识别',
#  '图像识别',
#  '算法研究员',
#  '售前工程师',
#  '售后工程师',
#  '其他技术职位',
#  '产品经理',
#  '网页产品经理',
#  '移动产品经理',
#  '产品助理',
#  '数据产品经理',
#  '电商产品经理',
#  '游戏策划',
#  '产品专员',
#  '产品总监',
#  '游戏制作人',
#  '产品VP',
#  '其他产品职位',
#  '视觉设计师',
#  '网页设计师',
#  'Flash设计师',
#  'APP设计师',
#  'UI设计师',
#  '平面设计师',
#  '美术设计师（2D/3D）',
#  '广告设计师',
#  '多媒体设计师',
#  '原画师',
#  '游戏特效',
#  '游戏界面设计师',
#  '游戏场景',
#  '游戏角色',
#  '游戏动作',
#  '三维/CAD/制图',
#  '美工',
#  '包装设计',
#  '设计师助理',
#  '动画设计师',
#  '插画师',
#  '交互设计师',
#  '无线交互设计师',
#  '网页交互设计师',
#  '硬件交互设计师',
#  '数据分析师',
#  '用户研究员',
#  '游戏数值策划',
#  'UX设计师',
#  '用户研究经理',
#  '用户研究总监',
#  '设计经理/主管',
#  '设计总监',
#  '视觉设计经理',
#  '视觉设计总监',
#  '交互设计经理/主管',
#  '交互设计总监',
#  '服装设计',
#  '工业设计',
#  '橱柜设计',
#  '家具设计',
#  '家居设计',
#  '珠宝设计',
#  '室内设计',
#  '陈列设计',
#  '景观设计',
#  '其他设计职位',
#  '用户运营',
#  '产品运营',
#  '数据运营',
#  '内容运营',
#  '活动运营',
#  '商家运营',
#  '品类运营',
#  '游戏运营',
#  '网络推广',
#  '网站运营',
#  '新媒体运营',
#  '社区运营',
#  '微信运营',
#  '微博运营',
#  '策略运营',
#  '线下拓展运营',
#  '电商运营',
#  '运营助理/专员',
#  '销售运营',
#  '副主编',
#  '内容编辑',
#  '文案策划',
#  '网站编辑',
#  '记者',
#  '采编',
#  '售前咨询',
#  '售后咨询',
#  '网络客服',
#  '客服经理',
#  '客服专员/助理',
#  '客服主管',
#  '客服总监',
#  '电话客服',
#  '咨询热线/呼叫中心客服',
#  '主编',
#  '运营总监',
#  'COO',
#  '客服总监',
#  '运营经理/主管',
#  '其他运营职位',
#  '市场营销',
#  '市场策划',
#  '市场顾问',
#  '市场推广',
#  'SEO',
#  'SEM',
#  '商务渠道',
#  '商业数据分析',
#  '活动策划',
#  '网络营销',
#  '海外市场',
#  '政府关系',
#  '媒介经理',
#  '广告协调',
#  '品牌公关',
#  '媒介专员',
#  '活动策划执行',
#  '媒介策划',
#  '会议活动销售',
#  '会议活动策划',
#  '会议活动执行',
#  '会展活动销售',
#  '会展活动策划',
#  '会展活动执行',
#  '广告创意',
#  '美术指导',
#  '广告设计师',
#  '策划经理',
#  '文案',
#  '广告制作',
#  '媒介投放',
#  '媒介合作',
#  '媒介顾问',
#  '广告审核',
#  '市场总监',
#  'CMO',
#  '公关总监',
#  '媒介总监',
#  '创意总监',
#  '其他市场职位',
#  '人力资源主管',
#  '招聘',
#  'HRBP',
#  '人力资源专员/助理',
#  '培训',
#  '薪资福利',
#  '绩效考核',
#  '人力资源经理',
#  '人力资源VP/CHO',
#  '人力资源总监',
#  '员工关系',
#  '组织发展',
#  '行政专员/助理',
#  '前台',
#  '行政主管',
#  '经理助理',
#  '后勤',
#  '商务司机',
#  '行政经理',
#  '行政总监',
#  '会计',
#  '出纳',
#  '财务顾问',
#  '结算',
#  '税务',
#  '审计',
#  '风控',
#  '财务经理',
#  'CFO',
#  '财务总监',
#  '财务主管',
#  '法务专员/助理',
#  '律师',
#  '专利',
#  '法律顾问',
#  '法务主管',
#  '法务经理',
#  '法务总监',
#  'CEO/总裁/总经理',
#  '副总裁/副总经理',
#  '事业部负责人',
#  '区域/分公司/代表处负责人',
#  '总裁/总经理/董事长助理',
#  '合伙人',
#  '创始人',
#  '董事会秘书',
#  '其他职能职位',
#  '销售专员',
#  '销售经理',
#  '客户代表',
#  '大客户代表',
#  'BD经理',
#  '商务渠道',
#  '渠道销售',
#  '代理商销售',
#  '销售助理',
#  '电话销售',
#  '销售顾问',
#  '商品经理',
#  '广告销售',
#  '网络营销',
#  '营销主管',
#  '销售总监',
#  '商务总监',
#  '区域总监',
#  '城市经理',
#  '销售VP',
#  '团队经理',
#  '其他销售职位',
#  '记者',
#  '编辑',
#  '采编',
#  '撰稿人',
#  '出版发行',
#  '校对录入',
#  '总编',
#  '自媒体',
#  '媒介经理',
#  '媒介专员',
#  '广告协调',
#  '品牌公关',
#  '活动策划执行',
#  '媒介策划',
#  '会议活动销售',
#  '会议活动策划',
#  '会议活动执行',
#  '会展活动销售',
#  '会展活动策划',
#  '会展活动执行',
#  '广告创意',
#  '美术指导',
#  '广告设计师',
#  '策划经理',
#  '文案',
#  '广告制作',
#  '媒介投放',
#  '媒介合作',
#  '媒介顾问',
#  '广告审核',
#  '助理',
#  '统筹制片人',
#  '执行制片人',
#  '导演/编导',
#  '摄影/影像师',
#  '视频编辑',
#  '音频编辑',
#  '经纪人',
#  '后期制作',
#  '影视制作',
#  '影视发行',
#  '影视策划',
#  '主持人/主播/DJ',
#  '演员/配音/模特',
#  '化妆/造型/服装',
#  '放映管理',
#  '录音/音效',
#  '制片人',
#  '编剧',
#  '其他传媒职位',
#  '投资经理',
#  '行业研究',
#  '资产管理',
#  '投资总监',
#  '投资VP',
#  '投资合伙人',
#  '融资',
#  '并购',
#  '投后管理',
#  '投资助理',
#  '其他投融资职位',
#  '投资顾问',
#  '风控',
#  '律师',
#  '资信评估',
#  '合规稽查',
#  '审计',
#  '法务',
#  '会计',
#  '清算',
#  '信用卡销售',
#  '分析师',
#  '柜员',
#  '商务渠道',
#  '大堂经理',
#  '理财顾问',
#  '客户经理',
#  '信贷管理',
#  '风控',
#  '金融产品经理',
#  '风控',
#  '催收员',
#  '分析师',
#  '投资经理',
#  '交易员',
#  '理财顾问',
#  '合规稽查',
#  '审计',
#  '清算',
#  '保险业务',
#  '精算师',
#  '保险理赔',
#  '其他金融职位',
#  '证券经纪人',
#  '证券分析师']

# %%
len(tag_list)
# Out:
# 421

# %%
tag_set = set(tag_list)

# %%
len(tag_set)
