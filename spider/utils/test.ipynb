# %%
import requests

# %%
import os

# %%
os.environ.get("http_proxy")
# Out:
# 'http://127.0.0.1:8123'

# %%
r = requests.get("http://123.207.153.235:23/get/")

# %%
r.status_code
# Out:
# 403

# %%
r = requests.get("http://123.207.153.235:23/get/", proxies= {
    'http': None,
    'https': None
})

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '141.54.99.71:9090'

# %%
proxies = {
    'http': None,
    'https': None
}

# %%
r = requests.get("http://123.207.153.235:23/get_all/", proxies=proxies)

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '[\n  "45.55.27.146:3128", \n  "106.39.179.169:80", \n  "222.165.215.129:80", \n  "123.56.86.187:3128", \n  "118.193.107.219:80", \n  "180.250.3.52:80", \n  "183.51.191.16:9999", \n  "177.66.171.103:8080", \n  "47.52.29.43:80", \n  "118.193.107.195:80", \n  "190.121.158.114:8080", \n  "103.206.246.110:8080", \n  "180.76.134.106:3128", \n  "118.193.107.193:80", \n  "70.169.70.88:80", \n  "200.5.83.150:3128", \n  "180.250.74.210:8080", \n  "119.90.63.3:3128", \n  "121.69.3.102:8080", \n  "118.193.107.54:80", \n  "201.18.14.178:8080", \n  "115.124.75.30:8080", \n  "212.9.239.166:3128", \n  "220.197.176.46:8080", \n  "111.56.5.42:8080", \n  "46.228.6.149:8081", \n  "103.55.48.126:8080", \n  "64.103.38.147:8080", \n  "94.230.243.6:8080", \n  "138.197.230.116:55555", \n  "168.0.158.52:8080", \n  "139.59.72.191:3128", \n  "123.136.27.202:8080", \n  "95.104.16.21:8080", \n  "217.61.123.55:80", \n  "112.140.184.136:3128", \n  "47.89.22.200:80", \n  "176.9.75.42:8080", \n  "110.50.84.59:8080",
# ...

# %%
import json

# %%
json.loads(r.text)
# Out:
# ['45.55.27.146:3128',
#  '106.39.179.169:80',
#  '222.165.215.129:80',
#  '123.56.86.187:3128',
#  '118.193.107.219:80',
#  '180.250.3.52:80',
#  '183.51.191.16:9999',
#  '177.66.171.103:8080',
#  '47.52.29.43:80',
#  '118.193.107.195:80',
#  '190.121.158.114:8080',
#  '103.206.246.110:8080',
#  '180.76.134.106:3128',
#  '118.193.107.193:80',
#  '70.169.70.88:80',
#  '200.5.83.150:3128',
#  '180.250.74.210:8080',
#  '119.90.63.3:3128',
#  '121.69.3.102:8080',
#  '118.193.107.54:80',
#  '201.18.14.178:8080',
#  '115.124.75.30:8080',
#  '212.9.239.166:3128',
#  '220.197.176.46:8080',
#  '111.56.5.42:8080',
#  '46.228.6.149:8081',
#  '103.55.48.126:8080',
#  '64.103.38.147:8080',
#  '94.230.243.6:8080',
#  '138.197.230.116:55555',
#  '168.0.158.52:8080',
#  '139.59.72.191:3128',
#  '123.136.27.202:8080',
#  '95.104.16.21:8080',
#  '217.61.123.55:80',
#  '112.140.184.136:3128',
#  '47.89.22.200:80',
#  '176.9.75.42:8080',
#  '110.50.84.59:8080',
#  '134.35.204.68:8080',
# ...
